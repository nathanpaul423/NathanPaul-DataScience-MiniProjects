# %%
import requests 
from bs4 import BeautifulSoup
import pandas as pd

# %%
url_list = [
        'https://www.truereligion.com/bootcut/last-chance-womens-jeans',
        'https://www.truereligion.com/curvy/last-chance-womens-jeans',
        'https://www.truereligion.com/skinny/last-chance-womens-jeans'
          ]

url = 'https://www.truereligion.com/robots.txt'

# %%
headers_user = {
    'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/106.0.0.0 Safari/537.36'
}

# %%
site = requests.get(url,allow_redirects=False,headers=headers_user)

# %%
robots = BeautifulSoup(site.content,'html.parser')

# %%
print(robots.prettify)
# Out:
# <bound method Tag.prettify of User-Agent: *
# Disallow: /Account-Show/
# Disallow: /Account-EditName/
# Disallow: /Account-EditEmail/
# Disallow: /Account-EditPassword/
# Disallow: /Address-List/
# Disallow: /PaymentInstruments-List/
# Disallow: /Account-OrderStatus/
# Disallow: /Order-History/
# Disallow: /Account-PasswordResetDialog
# Disallow: /Search-*?
# Disallow: /*search*
# Disallow: /Cart-Show/
# Disallow: /COShipping-Start/
# Disallow: /COSummary-Submit/
# Disallow: /on/demandware.store/Sites-TrueReligion-Site
# Disallow: /on/demandware.static/Sites-TrueReligion-Site/-/default/v
# Disallow: /*?q=
# Disallow: /*?j=
# Disallow: /*srule
# Disallow: /*&amp;dwvar
# Disallow: /*prefn1
# Disallow: /*prefv1
#
# Sitemap: https://www.truereligion.com/sitemap_0.xml>

# %%
def scrape(url):

  product_data = {
              'product_name':[],
              'brand_name':[],
              'original_price':[], 
              'strike_down_price':[], 
              'promo_price':[],
              'product_link':[],
              'image_link':[]
             }
  for i in url:
    site = requests.get(i,headers=headers_user)
    soup = BeautifulSoup(site.content, 'html.parser')
    product = soup.find_all('li',class_={'grid-tile odd-true in_stock','grid-tile odd-false in_stock'})

    for n in range(len(product)):
      ###
      #product_name
      if product[n].find('a',class_="name-link product-name") is not None:
        product_data['product_name'].append(product[n].find('a',class_="name-link product-name").text.strip())
      else:
        product_data['product_name'].append('None')

      #brand_name
      if product[n].find('a',class_="name-link product-name") is not None:
        x = product[n].find('a',class_="name-link product-name").text.strip().index(' ') #index of the first '(space)'
        brand = product[n].find('a',class_="name-link product-name").text.strip()
        brand = brand[:x]
        product_data['brand_name'].append(brand)
      else:
        product_data['brand_name'].append('None')

      
      #original price
      if product[n].find('span',class_="price-standard") is not None:
        product_data['original_price'].append(product[n].find('span',class_="price-standard").text.strip())
      else:
        product_data['original_price'].append('None')

      #strike_price
      if product[n].find('span',class_="price-sales strike-through") is not None:
        product_data['strike_down_price'].append(product[n].find('span',class_="price-sales strike-through").text.strip())
      else:
        product_data['strike_down_price'].append('None')
      
      #promo price
      if product[n].find('div',class_="price-promo") is not None:
        product_data['promo_price'].append(product[n].find('div',class_="price-promo").text.strip())
      else:
        product_data['promo_price'].append('None')

      #image
      if product[n].find('img',class_="firstimage") is not None:
        product_data['image_link'].append(product[n].find('img',class_="firstimage").get('src'))
      else:
        product_data['image_link'].append('None')

      #link
      if product[n].find('a',class_="name-link product-name") is not None:
        x = product[n].find('a',class_="name-link product-name").get('href')
        link = f'{i}{x}'
        product_data['product_link'].append(link)
      else:
        product_data['product_link'].append('None')
      ###

  return product_data

# %%
scrape_products = pd.DataFrame(scrape(url_list))
scrape_products
# Out:
#                           product_name brand_name original_price  \
# 0                   BECCA BOOTCUT JEAN      BECCA        $149.00
# 1                   BECCA BOOTCUT JEAN      BECCA        $179.00
# 2                   BECCA BOOTCUT JEAN      BECCA        $159.00
# 3      BECCA BIG T STITCH BOOTCUT JEAN      BECCA        $199.00
# 4      BECCA BIG T STITCH BOOTCUT JEAN      BECCA        $199.00
# 5      BECCA BIG T STITCH BOOTCUT JEAN      BECCA        $199.00
# 6    BECCA SUPER T STITCH BOOTCUT JEAN      BECCA        $239.00
# 7                   BECCA BOOTCUT JEAN      BECCA        $149.00
# 8                   BECCA BOOTCUT JEAN      BECCA        $159.00
# 9     JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 10    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 11    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $219.00
# 12  JENNIE HIGH RISE CURVY SKINNY JEAN     JENNIE        $179.00
# 13            JENNIE CURVY SKINNY JEAN     JENNIE        $159.00
# 14      JENNIE CURVY SKINNY ANKLE JEAN     JENNIE        $179.00
# 15                  STELLA SKINNY JEAN     STELLA        $159.00
# 16    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 17     STELLA BIG T STITCH SKINNY JEAN     STELLA        $199.00
# 18                  STELLA SKINNY JEAN     STELLA        $159.00
# 19                  STELLA SKINNY JEAN     STELLA        $159.00
# 20       JENNIE CURVY SKINNY CROP JEAN     JENNIE        $159.00
# 21    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 22      JENNIE BIG T CURVY SKINNY JEAN     JENNIE        $199.00
# 23       JENNIE HIGH RISE SUPER T JEAN     JENNIE        $219.00
# 24     STELLA BIG T STITCH SKINNY JEAN     STELLA        $199.00
# 25      JENNIE BIG T CURVY SKINNY JEAN     JENNIE        $199.00
# 26  JENNIE HIGH RISE CURVY SKINNY JEAN     JENNIE        $179.00
# 27    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $229.00
# 28                  STELLA SKINNY JEAN     STELLA        $159.00
# 29       JENNIE HIGH RISE CONTOUR JEAN     JENNIE        $159.00
# 30  STELLA STACKED SUPER T SKINNY JEAN     STELLA        $259.00
# 31     STELLA BIG T STITCH SKINNY JEAN     STELLA        $199.00
# 32   JENNIE MID RISE CURVY SKINNY JEAN     JENNIE        $179.00
# 33              JENNIE BIG T CROP JEAN     JENNIE        $199.00
# 34   JENNIE MID RISE CURVY SKINNY JEAN     JENNIE        $179.00
# 35    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 36       JENNIE CURVY SKINNY CROP JEAN     JENNIE        $159.00
# 37    JENNIE SUPER T CURVY SKINNY JEAN     JENNIE        $239.00
# 38   JENNIE MID RISE CURVY SKINNY JEAN     JENNIE        $149.00
# 39                  STELLA SKINNY JEAN     STELLA        $179.00
# 40   STELLA SUPER T STITCH SKINNY JEAN     STELLA        $239.00
#
#    strike_down_price promo_price  \
# 0            $119.97      $59.98
# 1               None      $89.50
# 2            $134.97      $67.48
# 3            $169.97      $84.98
# 4            $139.97      $55.99
# 5               None      $99.50
# 6            $199.97      $99.98
# 7             $99.97      $49.98
# 8            $114.97      $57.48
# 9            $199.97      $99.98
# 10              None     $119.50
# 11              None     $109.50
# 12           $144.97      $72.48
# 13              None        None
# 14           $149.97      $74.98
# 15           $134.97      $67.48
# 16           $199.97      $99.98
# 17           $139.97      $69.98
# 18           $134.97      $67.48
# 19            $99.97      $49.98
# 20           $134.97      $67.48
# 21           $139.97      $69.98
# 22           $169.97      $67.99
# 23           $139.97      $69.98
# 24           $169.97      $84.98
# 25           $139.97      $69.98
# 26           $119.97      $59.98
# 27           $139.97      $69.98
# 28            $99.97      $49.98
# 29           $109.97      $54.98
# 30           $219.97     $109.98
# 31           $119.97      $59.98
# 32           $149.97      $59.99
# 33           $119.97      $59.98
# 34           $149.97      $59.99
# 35           $199.97      $99.98
# 36           $134.97      $67.48
# 37           $159.97      $79.98
# 38            $99.97      $49.98
# 39           $124.97      $62.48
# 40           $199.97      $99.98
#
#                                          product_link  \
# 0   https://www.truereligion.com/bootcut/last-chan...
# 1   https://www.truereligion.com/bootcut/last-chan...
# 2   https://www.truereligion.com/bootcut/last-chan...
# 3   https://www.truereligion.com/bootcut/last-chan...
# 4   https://www.truereligion.com/bootcut/last-chan...
# 5   https://www.truereligion.com/bootcut/last-chan...
# 6   https://www.truereligion.com/bootcut/last-chan...
# 7   https://www.truereligion.com/bootcut/last-chan...
# 8   https://www.truereligion.com/bootcut/last-chan...
# 9   https://www.truereligion.com/curvy/last-chance...
# 10  https://www.truereligion.com/curvy/last-chance...
# 11  https://www.truereligion.com/curvy/last-chance...
# 12  https://www.truereligion.com/curvy/last-chance...
# 13  https://www.truereligion.com/curvy/last-chance...
# 14  https://www.truereligion.com/skinny/last-chanc...
# 15  https://www.truereligion.com/skinny/last-chanc...
# 16  https://www.truereligion.com/skinny/last-chanc...
# 17  https://www.truereligion.com/skinny/last-chanc...
# 18  https://www.truereligion.com/skinny/last-chanc...
# 19  https://www.truereligion.com/skinny/last-chanc...
# 20  https://www.truereligion.com/skinny/last-chanc...
# 21  https://www.truereligion.com/skinny/last-chanc...
# 22  https://www.truereligion.com/skinny/last-chanc...
# 23  https://www.truereligion.com/skinny/last-chanc...
# 24  https://www.truereligion.com/skinny/last-chanc...
# 25  https://www.truereligion.com/skinny/last-chanc...
# 26  https://www.truereligion.com/skinny/last-chanc...
# 27  https://www.truereligion.com/skinny/last-chanc...
# 28  https://www.truereligion.com/skinny/last-chanc...
# 29  https://www.truereligion.com/skinny/last-chanc...
# 30  https://www.truereligion.com/skinny/last-chanc...
# 31  https://www.truereligion.com/skinny/last-chanc...
# 32  https://www.truereligion.com/skinny/last-chanc...
# 33  https://www.truereligion.com/skinny/last-chanc...
# 34  https://www.truereligion.com/skinny/last-chanc...
# 35  https://www.truereligion.com/skinny/last-chanc...
# 36  https://www.truereligion.com/skinny/last-chanc...
# 37  https://www.truereligion.com/skinny/last-chanc...
# 38  https://www.truereligion.com/skinny/last-chanc...
# 39  https://www.truereligion.com/skinny/last-chanc...
# 40  https://www.truereligion.com/skinny/last-chanc...
#
#                                            image_link
# 0   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 1   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 2   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 3   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 4   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 5   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 6   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 7   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 8   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 9   https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 10  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 11  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 12  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 13  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 14  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 15  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 16  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 17  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 18  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 19  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 20  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 21  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 22  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 23  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 24  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 25  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 26  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 27  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 28  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 29  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 30  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 31  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 32  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 33  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 34  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 35  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 36  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 37  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 38  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 39  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...
# 40  https://cdn-us-ec.yottaa.net/5d66e8af4f1bbf5e3...

# %%
scrape_products.to_excel('product_dataset.xlsx')
