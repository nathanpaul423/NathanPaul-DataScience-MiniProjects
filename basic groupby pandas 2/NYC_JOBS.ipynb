# %%
import pandas as pd

# %%
data = pd.read_csv('NYC_Jobs.csv')

# %%
data.head()
# Out:
#    Job ID                         Agency Posting Type  # Of Positions  \
# 0  545837    HRA/DEPT OF SOCIAL SERVICES     Internal               1
# 1  534561          NYC HOUSING AUTHORITY     Internal               1
# 2  348560      ADMIN FOR CHILDREN'S SVCS     Internal               1
# 3  539352  DEPT OF HEALTH/MENTAL HYGIENE     External               1
# 4  549164       DEPARTMENT OF CORRECTION     Internal               1
#
#                                  Business Title  \
# 0                            PROJECT SPECIALIST
# 1                               DEPUTY DIRECTOR
# 2    Eligibility Coordinator / Adoption Liaison
# 3     Child Care Associate, Bureau of Childcare
# 4  Administrative Public Information Specialist
#
#               Civil Service Title Title Classification Title Code No Level  \
# 0  COMPUTER SPECIALIST (SOFTWARE)        Competitive-1         13632    03
# 1  ADMINISTRATIVE SUPERVISOR OF S        Competitive-1         10045    M3
# ...

# %%
data.describe()
# Out:
#               Job ID  # Of Positions  Salary Range From  Salary Range To  \
# count    5198.000000     5198.000000        5198.000000      5198.000000
# mean   529469.758561        2.164102       62397.438447     84498.382596
# std     43300.761294        6.059245       30104.987538     43274.381565
# min     87990.000000        1.000000           0.000000        15.450000
# 25%    529774.250000        1.000000       50972.000000     61598.000000
# 50%    539282.000000        1.000000       60010.000000     82043.000000
# 75%    549097.000000        1.000000       75504.000000    105000.000000
# max    556360.000000      125.000000      270000.000000    300000.000000
#
#        Recruitment Contact
# count                  0.0
# mean                   NaN
# std                    NaN
# min                    NaN
# 25%                    NaN
# 50%                    NaN
# 75%                    NaN
# max                    NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5198 entries, 0 to 5197
# Data columns (total 30 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Job ID                         5198 non-null   int64
#  1   Agency                         5198 non-null   object
#  2   Posting Type                   5198 non-null   object
#  3   # Of Positions                 5198 non-null   int64
#  4   Business Title                 5198 non-null   object
#  5   Civil Service Title            5198 non-null   object
#  6   Title Classification           5198 non-null   object
#  7   Title Code No                  5198 non-null   object
#  8   Level                          5198 non-null   object
#  9   Job Category                   5196 non-null   object
#  10  Full-Time/Part-Time indicator  4977 non-null   object
#  11  Career Level                   5196 non-null   object
# ...

# %%
data.groupby('Agency')['Salary Range From'].mean()
#mean of salary range by agencies
# Out:
# Agency
# ADMIN FOR CHILDREN'S SVCS          63682.863185
# ADMIN TRIALS AND HEARINGS          53014.136377
# BOARD OF CORRECTION                75504.000000
# BRONX COMMUNITY BOARD #1           58700.000000
# BRONX DISTRICT ATTORNEY            70942.314516
# CAMPAIGN FINANCE BOARD             67147.285714
# CIVILIAN COMPLAINT REVIEW BD       58319.083333
# CONFLICTS OF INTEREST BOARD        75000.000000
# CONSUMER AND WORKER PROTECTION     50359.726190
# CULTURAL AFFAIRS                      20.981400
# DEPARTMENT FOR THE AGING           56788.207336
# DEPARTMENT OF BUILDINGS            64742.937500
# DEPARTMENT OF BUSINESS SERV.       63740.811139
# DEPARTMENT OF CITY PLANNING        77436.675676
# DEPARTMENT OF CORRECTION           66906.642691
# DEPARTMENT OF FINANCE              78634.817727
# DEPARTMENT OF INVESTIGATION        51569.111111
# DEPARTMENT OF PROBATION            40348.333333
# DEPARTMENT OF SANITATION           36437.228000
# ...

# %%
data.loc[data['Agency']=='TECHNOLOGY & INNOVATION']
# Out:
#       Job ID                   Agency Posting Type  # Of Positions  \
# 169   509609  TECHNOLOGY & INNOVATION     Internal               1
# 179   435652  TECHNOLOGY & INNOVATION     Internal               1
# 223   535255  TECHNOLOGY & INNOVATION     Internal               1
# 315   529469  TECHNOLOGY & INNOVATION     Internal               2
# 1589  509631  TECHNOLOGY & INNOVATION     Internal               1
# 1681  529368  TECHNOLOGY & INNOVATION     Internal               1
# 2017  509631  TECHNOLOGY & INNOVATION     External               1
# 2063  520114  TECHNOLOGY & INNOVATION     Internal               1
# 2190  520079  TECHNOLOGY & INNOVATION     External               3
# 2253  435652  TECHNOLOGY & INNOVATION     External               1
# 3191  450631  TECHNOLOGY & INNOVATION     Internal               1
# 3239  529368  TECHNOLOGY & INNOVATION     External               1
# 3434  538050  TECHNOLOGY & INNOVATION     Internal               1
# ...

# %%
pd.DataFrame(data.groupby(['Agency','Posting Type'])['Salary Range From','Salary Range To'].mean())
# Out:
# C:\Users\Tokwa\AppData\Local\Temp\ipykernel_16088\908946733.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   pd.DataFrame(data.groupby(['Agency','Posting Type'])['Salary Range From','Salary Range To'].mean())
#                                           Salary Range From  Salary Range To
# Agency                      Posting Type
# ADMIN FOR CHILDREN'S SVCS   External           63892.963564     80179.271208
#                             Internal           63484.196839     79739.181618
# ADMIN TRIALS AND HEARINGS   External           53014.136377     61454.508846
#                             Internal           53014.136377     61454.508846
# BOARD OF CORRECTION         External           75504.000000     89880.500000
# ...                                                     ...              ...
# TAXI & LIMOUSINE COMMISSION Internal           56529.782393     78160.086108
# ...
