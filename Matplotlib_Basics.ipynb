# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from matplotlib.pyplot import figure

# %%
# %matplotlib inline

# %%
#data
years = list(range(2009,2017))
android = [6.8,67.22,220.67,451.62,761.29,1004.68,1160.21,1271.02]
ios = [24.89,46.6,89.27,130.13,150.79,191.43,225.85,216.07]
microsoft = [15.03,12.38,8.76,16.94,30.71,35.13,26.74,6.94]

# %%
#basic lines and default colors
plt.plot(years,android,label='android')
plt.plot(years,ios,label='apple')
plt.plot(years,microsoft,label='microsoft')
plt.legend()
plt.show()

# %%
#basic plot and applied colors
plt.plot(years,android,label='android',c='C2')
plt.plot(years,ios,label='apple',c='C0')
plt.plot(years,microsoft,label='microsoft',c='C1')
plt.legend()
plt.show()

# %%
x = np.linspace(0,10,10)
y1 = x**2.6
y2 = x**2.8
y3 = x**2.9

# %%
plt.plot(x,y1,label ='asd')
plt.plot(x,y2,label ='sad')
plt.plot(x,y3,label = 'das')
plt.legend()
plt.show()

# %%
#basic plot with color and line style
plt.plot(x,y1,label ='asd',ls='--')
plt.plot(x,y2,label ='sad',ls='-.')
plt.plot(x,y3,label = 'das',ls=':')
plt.legend()
plt.show()

# %%
#basic plot with color, line style, linewidth adjustment and dash_cap with resizing.
figure(figsize=(10, 10), dpi=80) # resizes the figure
plt.plot(x,y1,label ='asd',ls='--',dash_capstyle='Round',linewidth=4)
plt.plot(x,y2,label ='sad',ls='-.',linewidth=2)
plt.plot(x,y3,label = 'das',ls=':',dash_capstyle='Butt',linewidth=5)
plt.legend()
plt.show()

# %%
#basic plot with color, line style, linewidth adjustment and dash_cap with resizing. with markers 
figure(figsize=(10, 10), dpi=80) # resizes the figure
plt.plot(x,y1,label ='asd',ls='--',dash_capstyle='Round',linewidth=4, marker='o',ms=10)
plt.plot(x,y2,label ='sad',ls='-.',linewidth=2, marker='s', ms=5)
plt.plot(x,y3,label = 'das',ls=':',dash_capstyle='Butt',linewidth=5)
plt.legend()
plt.show()
