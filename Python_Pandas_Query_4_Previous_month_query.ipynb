# %%
import pandas as pd

# %%
df = pd.read_csv('sample_data/alerts-resolved-last-240-days_20230123_154112.csv')

# %%
# Assume you have a dataframe named `df` with a date column named `date`
df['timestamp'] = pd.to_datetime(df['timestamp'])

# %%
now = pd.datetime.now()
prev_month = df[(df['timestamp'].dt.month == 12) & (df['timestamp'].dt.year == 2022)]
# Out:
# <ipython-input-36-f9eb0f6b041e>:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   now = pd.datetime.now()

# %%
prev_month
# Out:
#                                         id  ticket_created resolved  \
# 108   9913b8d5-04c8-456e-bf43-ce1d85288499           False        t
# 123   9c92b1a7-48d0-4d68-9523-8a210f05dc1a           False        t
# 312   afdc64c0-26ab-4edf-bf6c-2e1bb91883b7           False        t
# 697   3f9c33a4-7a23-4cc7-8918-a77ad2874023           False        t
# 750   98e93750-e0dd-481d-9ca7-b546f5f32761           False        t
# ...                                    ...             ...      ...
# 9590  e7ebf231-d9b3-4ae8-be27-7222c5d3aaef            True        f
# 9591  25ebe98c-b1c8-4b66-b0ee-0efdb3cf85c4            True        f
# 9592  31779467-eb27-4ba7-ad24-8e56dd69356a           False        f
# 9593  f1fc5702-c2e6-4c25-ae76-7ddff2ad9661            True        f
# 9594  80280af6-6b31-4d58-be54-080bc5114ab4            True        f
#
#                  resolved_on  autoresolvemins muted                 timestamp  \
# ...

# %%
now.month
# Out:
# 1

# %%
df[df['timestamp'].dt.year == 2023]
# Out:
#                                         id  ticket_created resolved  \
# 545   672299f0-8b8e-4e43-9662-944e890b96e1           False        t
# 1613  f056d75b-95a6-4d62-826e-61f168ec5550           False        t
# 1864  a7dca5b8-420b-40f6-b9f8-1eca49da8a1b           False        t
# 1914  957d17d6-105f-455b-9ac3-e4332711e596           False        t
# 2495  491850ff-e5bd-45f5-8285-a4fcecf2e60f            True        t
# ...                                    ...             ...      ...
# 9532  33e7740a-140e-4c18-b405-e5a98d957bdb            True        f
# 9533  b4a5b489-04fb-4579-b94c-76114fe83b51            True        f
# 9534  fcff1193-7259-4f31-a229-915d97e997ef            True        f
# 9549  e2f56d51-6945-46f9-b8e0-28f882f8e094            True        f
# 9550  cdf1ad9a-8cca-4b8a-b3be-43dfcc3a16fb            True        f
#
#                  resolved_on  autoresolvemins muted                 timestamp  \
# ...

# %%
df['timestamp'].dt.month
# Out:
# 0       8
# 1       8
# 2       8
# 3       8
# 4       8
#        ..
# 9847    8
# 9848    8
# 9849    8
# 9850    8
# 9851    8
# Name: timestamp, Length: 9852, dtype: int64

# %%
df[df['timestamp'].dt.month == 9]
# Out:
#                                         id  ticket_created resolved  \
# 140   24d4b1ed-37f6-4e57-af38-42376eaea84e            True        t
# 227   8707b4be-b36d-40f9-98f7-023fa9ac633b           False        t
# 231   0bb0bdc0-26c8-4e70-8078-e30539e116c5           False        t
# 248   5b6a9f54-3d48-44c8-996d-649bbbd7afb3           False        t
# 294   a4c3fc98-246b-4f17-815c-9cb06c38455d            True        t
# ...                                    ...             ...      ...
# 9789  782d20c4-f075-4ecb-8a10-5980d4239760            True        f
# 9790  e513b9cb-de78-4629-8126-fd4543107d03            True        f
# 9791  a719d038-0c7d-41ce-8cb9-a9e34b9f6f54            True        f
# 9792  9a412a3c-c2d3-42de-888c-9792d1aef82c            True        f
# 9793  74e66b6e-6173-405d-b4f3-c3c1b9aee476            True        f
#
#                  resolved_on  autoresolvemins muted                 timestamp  \
# ...
